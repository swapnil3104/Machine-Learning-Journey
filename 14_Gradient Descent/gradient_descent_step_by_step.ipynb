# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
# Lets apply OLS
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
# Formula of the best fit line is given by:
# y = m*x + b

# %%
# Get the slope of the best fit line
# coefficient of the linear regression model is stored in the `coef_` attribute of the LinearRegression object. You can access it as follows:
#coefficient is m in formula of best fit line
reg.coef_
# Out:
# array([78.35063668])

# %%
# Get the intercept of the best fit line
# The intercept of the linear regression model is stored in the `intercept_` attribute of the LinearRegression object. You can access it as follows:
# intercept is b in formula of best fit line
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %%
# Lets apply Gradient Descent assuming slope is constant m = 78.35
# and let's assume the starting value for intercept b = 0
y_pred = ((78.35 * X) + 0).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS') # Plot the OLS regression line
plt.plot(X,y_pred,color='#00a65a',label='b = 0') # Plot the line with intercept = 0
plt.legend()
plt.show()

# %%
m = 78.35
b = 0
## Calculate the slope of the loss function with respect to the slope (m) of the best fit line
# Formula for the slope of the loss function with respect to m is given by:
# loss_slope = -2 * sum((y - (m*x) - b)

loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-209.27763408209216)

# %%
# Lets take learning rate = 0.1
lr = 0.1
# Formula for the step size is given by:
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
# Calculating the new intercept
b = b - step_size
b
# Out:
# np.float64(20.927763408209216)

# %%
y_pred1 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred1,color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 2
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-41.85552681641843)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-4.185552681641844)

# %%
b = b - step_size
b
# Out:
# np.float64(25.11331608985106)

# %%
y_pred2 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred2,color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred1,color='#A3E4D7',label='b = {}'.format(b))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-8.371105363283675)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-0.8371105363283675)

# %%
b = b - step_size
b
# Out:
# np.float64(25.95042662617943)

# %%
y_pred3 = ((78.35 * X) + b).reshape(4)

plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred3,color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred2,color='#A3E4D7',label='b = {}'.format(b))
plt.plot(X,y_pred1,color='#A3E4D7',label='b = {}'.format(b))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Lets apply Gradient Descent assuming slope is constant m = 78.35

b = -100 # Initial value for intercept
m = 78.35 # Initial value for slope
lr = 0.1  # Learning rate

epochs = 100

for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*X.ravel() - b) # Calculate the slope of the loss function
  b = b - (lr * loss_slope) # Update the intercept

  y_pred = m * X + b # Calculate the predicted values

  plt.plot(X,y_pred) # Plot the predicted line

plt.scatter(X,y)
